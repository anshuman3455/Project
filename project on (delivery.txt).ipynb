# %%
import numpy as np
import pandas as pd
# 25 bache
# 25 se 50 men
# 50 se 100 old

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\deliverytime.txt")

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
# ...

# %%
df.shape
# Out:
# (45593, 11)

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Type_of_order                  0
# Type_of_vehicle                0
# Time_taken(min)                0
# dtype: int64

# %% [markdown]
# # Total Type of order

# %%
df['Type_of_order'].value_counts()
# Out:
# Snack      11533
# Meal       11458
# Drinks     11322
# Buffet     11280
# Name: Type_of_order, dtype: int64

# %% [markdown]
# # Total Type vehicle

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: Type_of_vehicle, dtype: int64

# %% [markdown]
# # Time taken by type of order and type of vehicle

# %%
order = df.groupby('Type_of_order')['Time_taken(min)'].mean()
order
# Out:
# Type_of_order
# Buffet     26.283511
# Drinks     26.187953
# Meal       26.419270
# Snack      26.286309
# Name: Time_taken(min), dtype: float64

# %%
vehicle = df.groupby("Type_of_vehicle")['Time_taken(min)'].mean()
vehicle
# Out:
# Type_of_vehicle
# bicycle              26.426471
# electric_scooter     24.470110
# motorcycle           27.605674
# scooter              24.480754
# Name: Time_taken(min), dtype: float64

# %% [markdown]
# As per analysis we had seen that order type is not mendetory or not responsible  to have long delivery time spam but according to vehicle type thier is difference between the time taken to deliver the food.

# %% [markdown]
# # Delivery time taken on order by perticular  vehicle1

# %%
col = ['Type_of_order',"Type_of_vehicle",]
df2 = df.groupby(col)[['Time_taken(min)']].mean()
df2
# Out:
#                                  Time_taken(min)
# Type_of_order Type_of_vehicle
# Buffet        bicycle                  25.933333
#               electric_scooter         24.256628
#               motorcycle               27.566945
#               scooter                  24.526697
# Drinks        bicycle                  25.562500
#               electric_scooter         24.630137
#               motorcycle               27.395591
#               scooter                  24.514771
# Meal          bicycle                  27.260870
#               electric_scooter         24.540084
#               motorcycle               27.712183
#               scooter                  24.632115
# Snack         bicycle                  26.571429
#               electric_scooter         24.452772
#               motorcycle               27.743798
#               scooter                  24.254494

# %%
df['Time_taken(min)'].mean()
# Out:
# 26.29460662821047

# %%
a=df['Type_of_vehicle'].value_counts()
a
# Out:
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: Type_of_vehicle, dtype: int64

# %%
a.plot(kind="bar")
plt.xlabel("Type of vehicle")
plt.ylabel("Number of vehicle")
plt.title("Total number of vehicle")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 a.plot(kind="bar")
# ----> 2 plt.xlabel("Type of vehicle")
#       3 plt.ylabel("Number of vehicle")
#       4 plt.title("Total number of vehicle")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# As per perticular analysis electic scooter and scooter are more efficent than any other vehicle. Slighyly scooter is most efficent than all(expect buffet order) but the number of electric socter are less and motorcycle are more which makes average delivery time spam more longer.

# %% [markdown]
# # Age,rating mean according to order

# %%
mean_age = df.groupby('Type_of_order')['Delivery_person_Age'].mean()
mean_age
# Out:
# Type_of_order
# Buffet     29.583067
# Drinks     29.536478
# Meal       29.587013
# Snack      29.470736
# Name: Delivery_person_Age, dtype: float64

# %%
mean_rating = df.groupby('Type_of_order')['Delivery_person_Ratings'].mean()
mean_rating
# Out:
# Type_of_order
# Buffet     4.633121
# Drinks     4.631947
# Meal       4.630180
# Snack      4.634215
# Name: Delivery_person_Ratings, dtype: float64

# %% [markdown]
# # Age, rating mean according to vehicle

# %%
mean_age = df.groupby('Type_of_vehicle')['Delivery_person_Age'].mean()
mean_age
# Out:
# Type_of_vehicle
# bicycle              29.514706
# electric_scooter     29.682748
# motorcycle           29.542425
# scooter              29.512438
# Name: Delivery_person_Age, dtype: float64

# %%
mean_rating = df.groupby('Type_of_vehicle')['Delivery_person_Ratings'].mean()
mean_rating
# Out:
# Type_of_vehicle
# bicycle              4.320588
# electric_scooter     4.641846
# motorcycle           4.626253
# scooter              4.641968
# Name: Delivery_person_Ratings, dtype: float64

# %%
df.head(1)
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# 0                    75.912471        Snack      motorcycle                24

# %%
df['Age_type'] = np.where(
    df[]
)

# %%
Youth_Age = df[df['Delivery_person_Age'] <25 ]
Youth2_Age = df[df['Delivery_person_Age']<50] and df[df['Delivery_person_Age']<50]
Old_age = df[df['Delivery_person_Age']>50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 Youth_Age = df[df['Delivery_person_Age'] <25 ]
# ----> 2 Youth2_Age = df[df['Delivery_person_Age']<50] and df[df['Delivery_person_Age']<50]
#       3 Old_age = df[df['Delivery_person_Age']>50]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Youth2_Age
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
# ...

# %% [markdown]
# # Complete analyis of important columns
# mean ,median, standardization, minimum ,maximum

# %%
col = ['Type_of_order',"Type_of_vehicle",]
df2 = df.groupby(col).agg({
    "Delivery_person_Age": ['mean','median','std','min','max'],
    'Delivery_person_Ratings': ['mean','median','std','min','max'],
    'Time_taken(min)':['mean','median','std','min','max']
    
})
np.round(df2,2)
# Out:
#                                 Delivery_person_Age                        \
#                                                mean median    std min max
# Type_of_order Type_of_vehicle
# Buffet        bicycle                         28.53   29.0   7.70  15  50
#               electric_scooter                29.54   29.0   5.75  15  50
#               motorcycle                      29.56   29.0   5.63  15  50
#               scooter                         29.63   29.0   5.67  15  50
# Drinks        bicycle                         29.88   29.0   9.17  15  50
#               electric_scooter                29.90   30.0   5.93  15  50
#               motorcycle                      29.48   29.0   5.69  20  39
#               scooter                         29.54   29.0   5.76  15  50
# Meal          bicycle                         28.70   29.0   6.15  15  50
#               electric_scooter                29.73   29.0   5.89  15  50
# ...

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# ...

# %% [markdown]
# # Corelation between all columns

# %%
df.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5272\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.067449
# Delivery_person_Ratings                -0.067449                 1.000000
# Restaurant_latitude                    -0.001955                -0.004846
# Restaurant_longitude                   -0.006796                -0.011147
# Delivery_location_latitude              0.002359                -0.010198
# Delivery_location_longitude            -0.000593                -0.013350
# Time_taken(min)                         0.292708                -0.331103
#
#                              Restaurant_latitude  Restaurant_longitude  \
# ...

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# ...

# %% [markdown]
# # Visualization of data

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.hist(df['Delivery_person_Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.catplot(df,x='Type_of_order',y='Delivery_person_Age',hue='Type_of_vehicle',kind ='bar')

# %%
import seaborn as sns
sns.catplot(df,x='Type_of_order',y='Time_taken(min)',hue='Type_of_vehicle',kind ='bar')

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# ...

# %%
import sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sns.distplot(df['Delivery_person_Ratings'])
# Out:
#   Cell In[27], line 1
#     import sklearn.preprocessing import StandardScaler
#                                  ^
# SyntaxError: invalid syntax
